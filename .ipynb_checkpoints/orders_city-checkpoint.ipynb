# %%
import os 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
path=r'C:\Users\Wahbi\Desktop\omarnabi_exemnn\data project\Sales_Data'
alldata=pd.read_csv(path+'/'+'alldatanonull.csv')

# %%
alldata
# Out:
#         Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0                0   176558        USB-C Charging Cable                2
# 1                2   176559  Bose SoundSport Headphones                1
# 2                3   176560                Google Phone                1
# 3                4   176560            Wired Headphones                1
# 4                5   176561            Wired Headphones                1
# ...            ...      ...                         ...              ...
# 186300       11681   259353      AAA Batteries (4-pack)                3
# 186301       11682   259354                      iPhone                1
# 186302       11683   259355                      iPhone                1
# 186303       11684   259356      34in Ultrawide Monitor                1
# 186304       11685   259357        USB-C Charging Cable                1
#
#        Price Each      Order Date                         Purchase Address
# ...

# %%
alldata.isnull().sum()
# Out:
# Unnamed: 0          0
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
def city(x):
 return x.split(',')[1];

# %%
'682 Chestnut St, Boston, MA 02215'.split(' ')[2]
# Out:
# 'St,'

# %%
def  city2(x):
  return x.count(',')

# %%
alldata['count ,']=alldata['Purchase Address'].apply(city2)

# %%
alldata
# Out:
#         Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0                0   176558        USB-C Charging Cable                2
# 1                2   176559  Bose SoundSport Headphones                1
# 2                3   176560                Google Phone                1
# 3                4   176560            Wired Headphones                1
# 4                5   176561            Wired Headphones                1
# ...            ...      ...                         ...              ...
# 186300       11681   259353      AAA Batteries (4-pack)                3
# 186301       11682   259354                      iPhone                1
# 186302       11683   259355                      iPhone                1
# 186303       11684   259356      34in Ultrawide Monitor                1
# 186304       11685   259357        USB-C Charging Cable                1
#
#        Price Each      Order Date                         Purchase Address  \
# ...

# %%
alldata[alldata['count ,'] <2]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address, count ,, city]
# Index: []

# %%
alldata.drop(alldata[alldata['count ,'] <2].index, inplace = True)

# %%
alldata['city']=alldata['Purchase Address'].apply(city)

# %%
alldata
# Out:
#         Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0                0   176558        USB-C Charging Cable                2
# 1                2   176559  Bose SoundSport Headphones                1
# 2                3   176560                Google Phone                1
# 3                4   176560            Wired Headphones                1
# 4                5   176561            Wired Headphones                1
# ...            ...      ...                         ...              ...
# 186300       11681   259353      AAA Batteries (4-pack)                3
# 186301       11682   259354                      iPhone                1
# 186302       11683   259355                      iPhone                1
# 186303       11684   259356      34in Ultrawide Monitor                1
# 186304       11685   259357        USB-C Charging Cable                1
#
#        Price Each      Order Date                         Purchase Address  \
# ...

# %%
alldata.groupby('city')['city'].count()
# Out:
# city
#  Atlanta          14881
#  Austin            9905
#  Boston           19934
#  Dallas           14820
#  Los Angeles      29605
#  New York City    24876
#  Portland         12465
#  San Francisco    44732
#  Seattle          14732
# Name: city, dtype: int64

# %%
plt.bar(alldata.groupby('city')['city'].count().index,alldata.groupby('city')['city'].count())
plt.xticks(rotation="vertical")
plt.xlabel('recived orders')
plt.ylabel('city name')
# Out:
# Text(0, 0.5, 'city name')
